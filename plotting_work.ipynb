# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from plot_helpers import plot_vec, plot_vecs, autoscale_arrows
from sympy import *

# %%
u = Matrix([1,1])
v = Matrix([1,-2])

plot_vecs(u,v)

ax = plt.gca()

autoscale_arrows()
# ax.set_autoscale_on(True)
# ax.autoscale_view(True,True,True)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig = plt.gcf()
# fig.add_axes()

u = Matrix([1,1,1])
v = Matrix([1,-2,0])


plot_vecs(u,v)
autoscale_arrows()

# %%
v.tolist()[0]

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_aspect("equal")


# old way
from plot_helpers import Arrow3D
a = Arrow3D([0,1],[0,1],[0,3], mutation_scale=20, lw=1, arrowstyle="-|>", color="k")
ax.add_artist(a)
ax.set_xlim([-1,4])
ax.set_ylim([-1,4])
ax.set_zlim([-1,4])
# plt.draw()

# autoscale_arrows(ax)

# %%
ax.autoscale()

# %%
arrow = ax.get_children()[1]

# %%
type(arrow) == Arrow3D

# %%
arrow._verts3d[0][0]
